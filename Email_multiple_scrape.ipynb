# %% [markdown]
# <a href="https://colab.research.google.com/github/komaltp/Scrape-emails-from-any-website/blob/main/Email_multiple_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open('urls.txt', 'r')
for x in file.readlines():
  print(x)

# %%
import csv

# %%
from bs4 import BeautifulSoup
import requests
import requests.exceptions
import urllib.parse
from collections import deque
import re
import pandas as pd
from google.colab import files

# %%
#File = open("out.csv", "a")

# %%
file = open('urls.txt', 'r')
emails = set()
for x in file.readlines():
  print(x)
  user_url= str(x)
  urls= deque([user_url])
  scraped_urls= set()
  #emails = set()
  count=0
  try:
    while len(urls):
      count += 1
      if count == 200:
        break
      url=urls.popleft()
      scraped_urls.add(url)
      parts = urllib.parse.urlsplit(url)
      base_url = '{0.scheme}://{0.netloc}'.format(parts)
      path = url[:url.rfind('/')+1] if '/' in parts.path else url
      print('[%d] Processing %s' % (count, url))
      try:
        response = requests.get(url)
      except :
          continue
      new_emails = set(re.findall(r'[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.com', response.text, re.I))
      emails.update(new_emails)
      
      
      soup = BeautifulSoup(response.text, features="lxml")
      for anchor in soup.find_all("a"):
        link = anchor.attrs['href'] if 'href' in anchor.attrs else ''
        if link.startswith('/'):
          link = base_url + link
        elif not link.startswith('http'):
            link = path +link
        if not link in urls and not link in scraped_urls:
          urls.append(link)
  except KeyboardInterrupt:
   print('[-] Closing!')
  for mail in emails:
    print(mail)
df = pd.DataFrame(emails, columns=["Email"])
df.to_csv('email.csv', index=False)
files.download("email.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# [178] Processing https://www.ibm.com/cloud/watson-knowledge-catalog?mhsrc=ibmsearch_a&mhq=
# [179] Processing https://www.ibm.com/products/datapower-gateway?mhsrc=ibmsearch_a&mhq=
# [180] Processing https://www.ibm.com/products/filenet-content-manager?mhsrc=ibmsearch_a&mhq=
# [181] Processing https://www.ibm.com/cloud/object-storage?mhsrc=ibmsearch_a&mhq=
# [182] Processing https://www.ibm.com/products/cloud-pak-for-security?mhsrc=ibmsearch_a&mhq=
# [183] Processing https://www.ibm.com/products/z15?mhsrc=ibmsearch_a&mhq=
# [184] Processing https://www.ibm.com/cloud/bare-metal-servers?mhsrc=ibmsearch_a&mhq=
# [185] Processing https://www.ibm.com/?cc=us&lang=en&nojs=true&p=1
# [186] Processing https://www.ibm.com/?cc=us&lang=en&nojs=true&p=2
# [187] Processing https://www.ibm.com/?cc=us&lang=en&nojs=true&p=3
# [188] Processing https://www.ibm.com/?cc=us&lang=en&nojs=true&p=26
# ...
